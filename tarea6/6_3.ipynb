# %%
using Pkg
using OrdinaryDiffEq
using Trixi
using Plots
Pkg.activate(@__DIR__)
Pkg.instantiate()
# Out:
#   Activating project at `~/Documents/Hamburg/galerkin/tarea6`

# %%
function initial_condition_6(x, t, equations::CompressibleEulerEquations3D)
    
    ρ =1 # density
    v_1=sin(x[1])*cos(x[2])*cos(x[3]) 
    v_2=-cos(x[1])*sin(x[2])*cos(x[3]) 
    v_3=0 
    p=(100/1.4)+((1/16)*(cos(2*x[1])*cos(2*x[3])+2*cos(2*x[2])+2*cos(2*x[1])+cos(2*x[2])*cos(2*x[3]))) #pressure distribution
    
    
    return prim2cons(SVector(ρ,v_1,v_2,v_3,p),equations)
    
end
# Out:
# initial_condition_6 (generic function with 1 method)

# %%
function ex6_3()
    equations = CompressibleEulerEquations3D(1.4)#define the value of our λ = 1.4, and we got the compresible euler eqautions
    volume_flux = flux_ranocha
    surfacee_flux =flux_lax_friedrichs
    
    solver = DGSEM(polydeg=3, surface_flux=surfacee_flux,
               volume_integral=VolumeIntegralFluxDifferencing(volume_flux))
    coordinates_min=(-π,-π,-π)
    coordinates_max=(π,π,π)
    mesh = TreeMesh(coordinates_min, coordinates_max; periodicity=true, initial_refinement_level=3, n_cells_max=10000)
    semi = SemidiscretizationHyperbolic(mesh, equations, initial_condition_6, solver)
    
    
    tspan = (0.0, 5.0)
    ode = semidiscretize(semi, tspan)

    summary_callback = SummaryCallback()

    analysis_interval = 100
    analysis_callback = AnalysisCallback(semi, interval=analysis_interval)

    alive_callback = AliveCallback(analysis_interval=analysis_interval)

    save_solution = SaveSolutionCallback(interval=100,
                                     save_initial_solution=true,
                                     save_final_solution=true)

    stepsize_callback = StepsizeCallback(cfl=1.0)

    callbacks = CallbackSet(summary_callback,
                        analysis_callback,
                        alive_callback,
                        save_solution,
                        stepsize_callback);
    
    
    sol = solve(ode, RK4(), abstol=1.0e-6, reltol=1.0e-6, save_everystep=false, callback=callbacks);
    
    pl=plot(sol)

    savefig(pl,"sol.png")
    
end
# Out:
# ex6_3 (generic function with 1 method)

# %%
ex6_3()
# Out:
# ████████╗██████╗ ██╗██╗  ██╗██╗
# ╚══██╔══╝██╔══██╗██║╚██╗██╔╝██║
#    ██║   ██████╔╝██║ ╚███╔╝ ██║
#    ██║   ██╔══██╗██║ ██╔██╗ ██║
#    ██║   ██║  ██║██║██╔╝ ██╗██║
#    ╚═╝   ╚═╝  ╚═╝╚═╝╚═╝  ╚═╝╚═╝
#
# ┌──────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ SemidiscretizationHyperbolic                                                                     │
# │ ════════════════════════════                                                                     │
# │ #spatial dimensions: ………………………… 3                                                                │
# │ mesh: ………………………………………………………………… TreeMesh{3, Trixi.SerialTree{3}} with length 585                 │
# │ equations: …………………………………………………… CompressibleEulerEquations3D                                     │
# │ initial condition: ……………………………… initial_condition_6                                              │
# │ boundary conditions: ………………………… Trixi.BoundaryConditionPeriodic                                  │
# │ source terms: …………………………………………… nothing                                                          │
# │ solver: …………………………………………………………… DG                                                               │
# │ total #DOFs: ……………………………………………… 32768                                                            │
# └──────────────────────────────────────────────────────────────────────────────────────────────────┘
#
# ┌──────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ TreeMesh{3, Trixi.SerialTree{3}}                                                                 │
# │ ════════════════════════════════                                                                 │
# │ center: …………………………………………………………… [0.0, 0.0, 0.0]                                                  │
# │ length: …………………………………………………………… 6.283185307179586                                                │
# │ periodicity: ……………………………………………… (true, true, true)                                               │
# │ current #cells: ……………………………………… 585                                                              │
# │ maximum #cells: ……………………………………… 10000                                                            │
# └──────────────────────────────────────────────────────────────────────────────────────────────────┘
#
# ┌──────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ CompressibleEulerEquations3D                                                                     │
# │ ════════════════════════════                                                                     │
# │ #variables: ………………………………………………… 5                                                                │
# │ │ variable 1: …………………………………………… rho                                                              │
# │ │ variable 2: …………………………………………… rho_v1                                                           │
# │ │ variable 3: …………………………………………… rho_v2                                                           │
# │ │ variable 4: …………………………………………… rho_v3                                                           │
# │ │ variable 5: …………………………………………… rho_e                                                            │
# └──────────────────────────────────────────────────────────────────────────────────────────────────┘
#
# ┌──────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ DG{Float64}                                                                                      │
# │ ═══════════                                                                                      │
# │ basis: ……………………………………………………………… LobattoLegendreBasis{Float64}(polydeg=3)                         │
# │ mortar: …………………………………………………………… LobattoLegendreMortarL2{Float64}(polydeg=3)                      │
# │ surface integral: ………………………………… SurfaceIntegralWeakForm                                          │
# │ │ surface flux: ……………………………………… FluxLaxFriedrichs(max_abs_speed_naive)                           │
# │ volume integral: …………………………………… VolumeIntegralFluxDifferencing                                   │
# │ │ volume flux: ………………………………………… flux_ranocha                                                     │
# └──────────────────────────────────────────────────────────────────────────────────────────────────┘
#
# ┌──────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ AnalysisCallback                                                                                 │
# │ ════════════════                                                                                 │
# │ interval: ……………………………………………………… 100                                                              │
# │ analyzer: ……………………………………………………… LobattoLegendreAnalyzer{Float64}(polydeg=6)                      │
# │ │ error 1: …………………………………………………… l2_error                                                         │
# │ │ error 2: …………………………………………………… linf_error                                                       │
# │ │ integral 1: …………………………………………… entropy_timederivative                                           │
# │ save analysis to file: …………………… no                                                               │
# └──────────────────────────────────────────────────────────────────────────────────────────────────┘
#
# ┌──────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ AliveCallback                                                                                    │
# │ ═════════════                                                                                    │
# │ interval: ……………………………………………………… 10                                                               │
# └──────────────────────────────────────────────────────────────────────────────────────────────────┘
#
# ┌──────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ SaveSolutionCallback                                                                             │
# │ ════════════════════                                                                             │
# │ interval: ……………………………………………………… 100                                                              │
# │ solution variables: …………………………… cons2prim                                                        │
# │ save initial solution: …………………… yes                                                              │
# │ save final solution: ………………………… yes                                                              │
# │ output directory: ………………………………… /Users/macbookprouser/Documents/Hamburg/galerkin/tarea6/out      │
# └──────────────────────────────────────────────────────────────────────────────────────────────────┘
#
# ┌──────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ StepsizeCallback                                                                                 │
# │ ════════════════                                                                                 │
# │ CFL number: ………………………………………………… 1.0                                                              │
# └──────────────────────────────────────────────────────────────────────────────────────────────────┘
#
# ┌──────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ Time integration                                                                                 │
# │ ════════════════                                                                                 │
# │ Start time: ………………………………………………… 0.0                                                              │
# │ Final time: ………………………………………………… 5.0                                                              │
# │ time integrator: …………………………………… RK4                                                              │
# │ adaptive: ……………………………………………………… true                                                             │
# │ abstol: …………………………………………………………… 1.0e-6                                                           │
# │ reltol: …………………………………………………………… 1.0e-6                                                           │
# │ controller: ………………………………………………… PIController{Rational{Int64}}(7//40, 1//10)                      │
# └──────────────────────────────────────────────────────────────────────────────────────────────────┘
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#  Simulation running 'CompressibleEulerEquations3D' with DGSEM(polydeg=3)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#  #timesteps:                  0                run time:       6.62500000e-06 s
#  Δt:             0.00000000e+00                time/DOF/rhs!:         NaN s
#  sim. time:      0.00000000e+00
#  #DOF:                    32768
#  #elements:                 512
#
#  Variable:       rho              rho_v1           rho_v2           rho_v3           rho_e
#  L2 error:       9.86937119e-17   7.68535048e-05   7.68535048e-05   0.00000000e+00   7.45715226e-04
#  Linf error:     4.44089210e-16   4.65865405e-04   4.65865405e-04   0.00000000e+00   3.22286736e-03
#  ∑∂S/∂U ⋅ Uₜ :  -1.70525433e-18
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#
# #timesteps:     10 │ Δt: 9.4582e-03 │ sim. time: 6.5110e-02 │ run time: 4.4036e-01 s
# #timesteps:     20 │ Δt: 6.0359e-03 │ sim. time: 1.4035e-01 │ run time: 8.5849e-01 s
# #timesteps:     30 │ Δt: 6.2231e-03 │ sim. time: 2.0281e-01 │ run time: 1.2159e+00 s
# #timesteps:     40 │ Δt: 6.2112e-03 │ sim. time: 2.6503e-01 │ run time: 1.5870e+00 s
# #timesteps:     50 │ Δt: 6.0089e-03 │ sim. time: 3.2625e-01 │ run time: 1.9858e+00 s
# #timesteps:     60 │ Δt: 5.9233e-03 │ sim. time: 3.8567e-01 │ run time: 2.3461e+00 s
# #timesteps:     70 │ Δt: 5.9054e-03 │ sim. time: 4.4480e-01 │ run time: 2.7126e+00 s
# #timesteps:     80 │ Δt: 5.8969e-03 │ sim. time: 5.0380e-01 │ run time: 3.0721e+00 s
# #timesteps:     90 │ Δt: 5.8935e-03 │ sim. time: 5.6275e-01 │ run time: 3.4270e+00 s
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#  Simulation running 'CompressibleEulerEquations3D' with DGSEM(polydeg=3)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#  #timesteps:                100                run time:       3.94879020e+00 s
#  Δt:             5.89257276e-03                time/DOF/rhs!:  1.74525817e-07 s
#  sim. time:      6.21675583e-01
#  #DOF:                    32768
#  #elements:                 512
#
#  Variable:       rho              rho_v1           rho_v2           rho_v3           rho_e
#  L2 error:       4.02308137e-04   3.89559343e-02   3.89559343e-02   5.42014438e-02   2.44496636e-02
#  Linf error:     1.51775307e-03   9.36336518e-02   9.36336526e-02   1.60816597e-01   1.07577260e-01
#  ∑∂S/∂U ⋅ Uₜ :  -4.59194298e-08
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#
# #timesteps:    110 │ Δt: 5.8927e-03 │ sim. time: 6.8060e-01 │ run time: 4.2112e+00 s
# #timesteps:    120 │ Δt: 5.8932e-03 │ sim. time: 7.3953e-01 │ run time: 4.5649e+00 s
# #timesteps:    130 │ Δt: 5.8940e-03 │ sim. time: 7.9847e-01 │ run time: 4.9163e+00 s
# #timesteps:    140 │ Δt: 5.8949e-03 │ sim. time: 8.5741e-01 │ run time: 5.2659e+00 s
# #timesteps:    150 │ Δt: 5.8957e-03 │ sim. time: 9.1637e-01 │ run time: 5.6277e+00 s
# #timesteps:    160 │ Δt: 5.8965e-03 │ sim. time: 9.7533e-01 │ run time: 5.9833e+00 s
# #timesteps:    170 │ Δt: 5.8972e-03 │ sim. time: 1.0343e+00 │ run time: 6.3494e+00 s
# #timesteps:    180 │ Δt: 5.8976e-03 │ sim. time: 1.0933e+00 │ run time: 6.7041e+00 s
# #timesteps:    190 │ Δt: 5.8979e-03 │ sim. time: 1.1522e+00 │ run time: 7.1073e+00 s
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#  Simulation running 'CompressibleEulerEquations3D' with DGSEM(polydeg=3)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#  #timesteps:                200                run time:       7.60517338e+00 s
#  Δt:             5.89780563e-03                time/DOF/rhs!:  1.69549634e-07 s
#  sim. time:      1.21122702e+00
#  #DOF:                    32768
#  #elements:                 512
#
#  Variable:       rho              rho_v1           rho_v2           rho_v3           rho_e
#  L2 error:       7.62666113e-04   7.60226180e-02   7.60226180e-02   1.01616389e-01   7.11348566e-02
#  Linf error:     2.79848369e-03   2.12467867e-01   2.12467871e-01   3.36096584e-01   3.45123245e-01
#  ∑∂S/∂U ⋅ Uₜ :  -2.14090607e-07
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#
# #timesteps:    210 │ Δt: 5.8975e-03 │ sim. time: 1.2702e+00 │ run time: 7.8815e+00 s
# #timesteps:    220 │ Δt: 5.8969e-03 │ sim. time: 1.3292e+00 │ run time: 8.2347e+00 s
# #timesteps:    230 │ Δt: 5.8960e-03 │ sim. time: 1.3881e+00 │ run time: 8.5840e+00 s
# #timesteps:    240 │ Δt: 5.8950e-03 │ sim. time: 1.4471e+00 │ run time: 8.9369e+00 s
# #timesteps:    250 │ Δt: 5.8940e-03 │ sim. time: 1.5060e+00 │ run time: 9.2878e+00 s
# #timesteps:    260 │ Δt: 5.8930e-03 │ sim. time: 1.5650e+00 │ run time: 9.6401e+00 s
# #timesteps:    270 │ Δt: 5.8920e-03 │ sim. time: 1.6239e+00 │ run time: 9.9896e+00 s
# #timesteps:    280 │ Δt: 5.8914e-03 │ sim. time: 1.6828e+00 │ run time: 1.0343e+01 s
# #timesteps:    290 │ Δt: 5.8908e-03 │ sim. time: 1.7417e+00 │ run time: 1.0695e+01 s
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#  Simulation running 'CompressibleEulerEquations3D' with DGSEM(polydeg=3)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#  #timesteps:                300                run time:       1.11717112e+01 s
#  Δt:             5.89018344e-03                time/DOF/rhs!:  1.65266143e-07 s
#  sim. time:      1.80062766e+00
#  #DOF:                    32768
#  #elements:                 512
#
#  Variable:       rho              rho_v1           rho_v2           rho_v3           rho_e
#  L2 error:       1.01341550e-03   1.12581736e-01   1.12581736e-01   1.42168726e-01   1.25247142e-01
#  Linf error:     3.66371919e-03   3.46968187e-01   3.46968187e-01   5.41425160e-01   5.78855611e-01
#  ∑∂S/∂U ⋅ Uₜ :  -5.63437172e-07
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#
# #timesteps:    310 │ Δt: 5.8898e-03 │ sim. time: 1.8595e+00 │ run time: 1.1434e+01 s
# #timesteps:    320 │ Δt: 5.8895e-03 │ sim. time: 1.9184e+00 │ run time: 1.1787e+01 s
# #timesteps:    330 │ Δt: 5.8892e-03 │ sim. time: 1.9773e+00 │ run time: 1.2139e+01 s
# #timesteps:    340 │ Δt: 5.8889e-03 │ sim. time: 2.0362e+00 │ run time: 1.2491e+01 s
# #timesteps:    350 │ Δt: 5.8886e-03 │ sim. time: 2.0951e+00 │ run time: 1.2848e+01 s
# #timesteps:    360 │ Δt: 5.8881e-03 │ sim. time: 2.1540e+00 │ run time: 1.3198e+01 s
# #timesteps:    370 │ Δt: 5.8873e-03 │ sim. time: 2.2129e+00 │ run time: 1.3550e+01 s
# #timesteps:    380 │ Δt: 5.8859e-03 │ sim. time: 2.2717e+00 │ run time: 1.3900e+01 s
# #timesteps:    390 │ Δt: 5.8832e-03 │ sim. time: 2.3306e+00 │ run time: 1.4253e+01 s
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#  Simulation running 'CompressibleEulerEquations3D' with DGSEM(polydeg=3)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#  #timesteps:                400                run time:       1.47267575e+01 s
#  Δt:             5.87859654e-03                time/DOF/rhs!:  1.65088630e-07 s
#  sim. time:      2.38937565e+00
#  #DOF:                    32768
#  #elements:                 512
#
#  Variable:       rho              rho_v1           rho_v2           rho_v3           rho_e
#  L2 error:       1.13488418e-03   1.47993924e-01   1.47993924e-01   1.74193446e-01   1.73907483e-01
#  Linf error:     3.85520071e-03   4.60709701e-01   4.60709701e-01   7.46643776e-01   7.53811555e-01
#  ∑∂S/∂U ⋅ Uₜ :  -1.88006118e-06
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#
# #timesteps:    410 │ Δt: 5.8719e-03 │ sim. time: 2.4481e+00 │ run time: 1.4992e+01 s
# #timesteps:    420 │ Δt: 5.8638e-03 │ sim. time: 2.5068e+00 │ run time: 1.5344e+01 s
# #timesteps:    430 │ Δt: 5.8562e-03 │ sim. time: 2.5654e+00 │ run time: 1.5695e+01 s
# #timesteps:    440 │ Δt: 5.8508e-03 │ sim. time: 2.6239e+00 │ run time: 1.6047e+01 s
# #timesteps:    450 │ Δt: 5.8478e-03 │ sim. time: 2.6824e+00 │ run time: 1.6397e+01 s
# #timesteps:    460 │ Δt: 5.8467e-03 │ sim. time: 2.7409e+00 │ run time: 1.6750e+01 s
# #timesteps:    470 │ Δt: 5.8470e-03 │ sim. time: 2.7994e+00 │ run time: 1.7100e+01 s
# #timesteps:    480 │ Δt: 5.8478e-03 │ sim. time: 2.8578e+00 │ run time: 1.7452e+01 s
# #timesteps:    490 │ Δt: 5.8491e-03 │ sim. time: 2.9163e+00 │ run time: 1.7804e+01 s
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#  Simulation running 'CompressibleEulerEquations3D' with DGSEM(polydeg=3)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#  #timesteps:                500                run time:       1.82805729e+01 s
#  Δt:             5.85059966e-03                time/DOF/rhs!:  1.64959849e-07 s
#  sim. time:      2.97481315e+00
#  #DOF:                    32768
#  #elements:                 512
#
#  Variable:       rho              rho_v1           rho_v2           rho_v3           rho_e
#  L2 error:       1.19644692e-03   1.81361188e-01   1.81361188e-01   1.98193143e-01   2.16483713e-01
#  Linf error:     4.41246543e-03   5.53508249e-01   5.53508249e-01   8.86309571e-01   8.83595218e-01
#  ∑∂S/∂U ⋅ Uₜ :  -5.76646859e-06
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# #timesteps:    510 │ Δt: 5.8520e-03 │ sim. time: 3.0333e+00 │ run time: 1.8545e+01 s
# #timesteps:    520 │ Δt: 5.8529e-03 │ sim. time: 3.0919e+00 │ run time: 1.8897e+01 s
# #timesteps:    530 │ Δt: 5.8533e-03 │ sim. time: 3.1504e+00 │ run time: 1.9250e+01 s
# #timesteps:    540 │ Δt: 5.8526e-03 │ sim. time: 3.2089e+00 │ run time: 1.9599e+01 s
# #timesteps:    550 │ Δt: 5.8506e-03 │ sim. time: 3.2674e+00 │ run time: 2.0023e+01 s
# #timesteps:    560 │ Δt: 5.8478e-03 │ sim. time: 3.3259e+00 │ run time: 2.0395e+01 s
# #timesteps:    570 │ Δt: 5.8451e-03 │ sim. time: 3.3844e+00 │ run time: 2.0748e+01 s
# #timesteps:    580 │ Δt: 5.8432e-03 │ sim. time: 3.4428e+00 │ run time: 2.1097e+01 s
# #timesteps:    590 │ Δt: 5.8427e-03 │ sim. time: 3.5013e+00 │ run time: 2.1449e+01 s
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#  Simulation running 'CompressibleEulerEquations3D' with DGSEM(polydeg=3)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#  #timesteps:                600                run time:       2.19220184e+01 s
#  Δt:             5.84351156e-03                time/DOF/rhs!:  1.69285200e-07 s
#  sim. time:      3.55968133e+00
#  #DOF:                    32768
#  #elements:                 512
#
#  Variable:       rho              rho_v1           rho_v2           rho_v3           rho_e
#  L2 error:       1.28274122e-03   2.11853108e-01   2.11853108e-01   2.16333456e-01   2.57729592e-01
#  Linf error:     4.62303203e-03   6.39731578e-01   6.39731578e-01   1.00074574e+00   1.31088401e+00
#  ∑∂S/∂U ⋅ Uₜ :  -1.12257825e-05
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#
# #timesteps:    610 │ Δt: 5.8457e-03 │ sim. time: 3.6181e+00 │ run time: 2.2194e+01 s
# #timesteps:    620 │ Δt: 5.8499e-03 │ sim. time: 3.6766e+00 │ run time: 2.2550e+01 s
# #timesteps:    630 │ Δt: 5.8526e-03 │ sim. time: 3.7351e+00 │ run time: 2.2902e+01 s
# #timesteps:    640 │ Δt: 5.8571e-03 │ sim. time: 3.7937e+00 │ run time: 2.3255e+01 s
# #timesteps:    650 │ Δt: 5.8618e-03 │ sim. time: 3.8523e+00 │ run time: 2.3605e+01 s
# #timesteps:    660 │ Δt: 5.8667e-03 │ sim. time: 3.9109e+00 │ run time: 2.3957e+01 s
# #timesteps:    670 │ Δt: 5.8720e-03 │ sim. time: 3.9696e+00 │ run time: 2.4307e+01 s
# #timesteps:    680 │ Δt: 5.8768e-03 │ sim. time: 4.0283e+00 │ run time: 2.4661e+01 s
# #timesteps:    690 │ Δt: 5.8812e-03 │ sim. time: 4.0871e+00 │ run time: 2.5011e+01 s
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#  Simulation running 'CompressibleEulerEquations3D' with DGSEM(polydeg=3)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#  #timesteps:                700                run time:       2.54865008e+01 s
#  Δt:             5.88530473e-03                time/DOF/rhs!:  1.65337598e-07 s
#  sim. time:      4.14597704e+00
#  #DOF:                    32768
#  #elements:                 512
#
#  Variable:       rho              rho_v1           rho_v2           rho_v3           rho_e
#  L2 error:       1.51572573e-03   2.38351602e-01   2.38351602e-01   2.28310873e-01   3.04202466e-01
#  Linf error:     8.33266562e-03   1.05096291e+00   1.05096291e+00   1.13769553e+00   1.74867985e+00
#  ∑∂S/∂U ⋅ Uₜ :  -2.60342299e-05
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#
# #timesteps:    710 │ Δt: 5.8884e-03 │ sim. time: 4.2048e+00 │ run time: 2.5759e+01 s
# #timesteps:    720 │ Δt: 5.8905e-03 │ sim. time: 4.2637e+00 │ run time: 2.6112e+01 s
# #timesteps:    730 │ Δt: 5.8915e-03 │ sim. time: 4.3227e+00 │ run time: 2.6464e+01 s
# #timesteps:    740 │ Δt: 5.8914e-03 │ sim. time: 4.3816e+00 │ run time: 2.6815e+01 s
# #timesteps:    750 │ Δt: 5.8900e-03 │ sim. time: 4.4405e+00 │ run time: 2.7169e+01 s
# #timesteps:    760 │ Δt: 5.8884e-03 │ sim. time: 4.4994e+00 │ run time: 2.7519e+01 s
# #timesteps:    770 │ Δt: 5.8862e-03 │ sim. time: 4.5582e+00 │ run time: 2.7880e+01 s
# #timesteps:    780 │ Δt: 5.8841e-03 │ sim. time: 4.6171e+00 │ run time: 2.8230e+01 s
# #timesteps:    790 │ Δt: 5.8824e-03 │ sim. time: 4.6759e+00 │ run time: 2.8585e+01 s
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#  Simulation running 'CompressibleEulerEquations3D' with DGSEM(polydeg=3)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#  #timesteps:                800                run time:       2.90575762e+01 s
#  Δt:             5.88158549e-03                time/DOF/rhs!:  1.65674456e-07 s
#  sim. time:      4.73474557e+00
#  #DOF:                    32768
#  #elements:                 512
#
#  Variable:       rho              rho_v1           rho_v2           rho_v3           rho_e
#  L2 error:       1.77876379e-03   2.58492912e-01   2.58492912e-01   2.33808664e-01   3.36121978e-01
#  Linf error:     9.15688990e-03   1.19700576e+00   1.19700577e+00   1.45413287e+00   3.67406867e+00
#  ∑∂S/∂U ⋅ Uₜ :  -4.84589136e-05
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#
# #timesteps:    810 │ Δt: 5.8814e-03 │ sim. time: 4.7936e+00 │ run time: 2.9326e+01 s
# #timesteps:    820 │ Δt: 5.8821e-03 │ sim. time: 4.8524e+00 │ run time: 2.9678e+01 s
# #timesteps:    830 │ Δt: 5.9095e-03 │ sim. time: 4.9112e+00 │ run time: 3.0029e+01 s
# #timesteps:    840 │ Δt: 5.8852e-03 │ sim. time: 4.9701e+00 │ run time: 3.0382e+01 s
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#  Simulation running 'CompressibleEulerEquations3D' with DGSEM(polydeg=3)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#  #timesteps:                846                run time:       3.07153772e+01 s
#  Δt:             5.14082845e-04                time/DOF/rhs!:  1.64868734e-07 s
#  sim. time:      5.00000000e+00
#  #DOF:                    32768
#  #elements:                 512
#
#  Variable:       rho              rho_v1           rho_v2           rho_v3           rho_e
#  L2 error:       1.83396106e-03   2.64744718e-01   2.64744718e-01   2.34473112e-01   3.40147210e-01
#  Linf error:     1.29059199e-02   1.27247919e+00   1.27247919e+00   1.65240299e+00   5.59406545e+00
#  ∑∂S/∂U ⋅ Uₜ :  -6.30721090e-05
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# Trixi simulation finished.  Final time: 5.0  Time steps: 846 (accepted), 848 (total)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
